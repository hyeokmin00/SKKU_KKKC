# %% [markdown]
# 회사 변수명
#         1. company_id
#         2. name
#         3. category
#         4. description
#         5. link
#         6. salary
#         7. logo
#         8. location
#         9. CEO

# %%
import os, sys
# PWD = os.getenv('PWD')
PWD = os.path.abspath('.')

PROJ_MISSING_MSG = """Set an enviroment variable:\n
`DJANGO_PROJECT=your_project_name`\n
or call:\n
`init_django(your_project_name)`
"""

def init_django(project_name=None):
    os.chdir(PWD)
    project_name = project_name or os.environ.get('DJANGO_PROJECT') or None
    if project_name == None:
        raise Exception(PROJ_MISSING_MSG)
    sys.path.insert(0, os.getenv('PWD'))
    os.environ.setdefault('DJANGO_SETTINGS_MODULE', f'{project_name}.settings')
    os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
    import django
    django.setup()

# %%
init_django('jobconnect') #project name

# %%
import csv
from board.models import Board  # myapp은 앱 이름으로 적절하게 변경해야합니다.

def import_data_from_csv():
    with open('etc/data.csv', 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            Board.objects.create(
                name=row['name'],
                category=row['category'],
                description=row['description'],
                link=row['link'],
                salary= None,
                logo= None,
                location=row['location'],
                ceo=row['ceo']
            )
        print('Data imported successfully!')

if __name__ == "__main__":
    import_data_from_csv()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shont\github\workspace\ai_basics\10_Web\jobconnect\csv_to_mysql.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>         print('Data imported successfully!')
#      <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a>     import_data_from_csv()
#
# c:\Users\shont\github\workspace\ai_basics\10_Web\jobconnect\csv_to_mysql.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> def import_data_from_csv():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     with open('data.csv', 'r', encoding='utf-8') as csvfile:
#       <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>         reader = csv.DictReader(csvfile)
#       <a href='vscode-notebook-cell:/c%3A/Users/shont/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>         for row in reader:
#
# File c:\Users\shont\miniconda3\envs\py39_django\lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'

# %% [markdown]
# 코멘트 변수명
#         1. job_category
#         2. loacation
#         3. status
#         4. created_at
#         5. title
#         6. content_pros
#         7. content_cons
#         8. content_hope
#         9. star
#         10. star_1
#         11. star_2
#         12. star_3
#         13. star_4
#         14. star_5

# %%
import csv
from board.models import Comment 

def import_comment_data_from_csv():
    with open('comment.csv', 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            Comment.objects.create(
                job_category=row['job_category'],
                location=row['location'],
                status=row['status'].lower() in ['true', '1', 'yes'],  
                is_delete=row['is_delete'].lower() in ['true', '1', 'yes'],  
                title=row['title'],
                content_pros=row['content_pros'],
                content_cons=row['content_cons'],
                content_hope=row['content_hope'],
                star=int(row['star']),
                star_1=int(row['star_1']),
                star_2=int(row['star_2']),
                star_3=int(row['star_3']),
                star_4=int(row['star_4']),
                star_5=int(row['star_5'])
            )
        print('Comment data imported successfully!')

if __name__ == "__main__":
    import_comment_data_from_csv()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a>         print('Comment data imported successfully!')
#      <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a>     import_comment_data_from_csv()
#
# /Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb Cell 5 line 5
#       <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> def import_comment_data_from_csv():
# ----> <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     with open('comment.csv', 'r', encoding='utf-8') as csvfile:
#       <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>         reader = csv.DictReader(csvfile)
#       <a href='vscode-notebook-cell:/Users/sh/github/workspace/ai_basics/10_Web/jobconnect/csv_to_mysql.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>         for row in reader:
#
# File ~/anaconda3/envs/py39_django/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'comment.csv'

# %%
from board.models import Board 
Board.objects.create(
                name='회사1',
                category='직종1',
                description='설명1',
                link='링크1',
                salary='연봉1',
                logo='로고1',
                location='위치1',
                ceo='대표1',
            )
# Out:
# <Board: Board object (1)>
